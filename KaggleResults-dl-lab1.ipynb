# %%
# Remove the directory if it exists
# !rm -rf DeepLearning 
# !rm -rf checkpoints

# Clone the repository again
# !git clone https://github.com/DieppDiepp/DeepLearning.git

# Run script
# !python /kaggle/working/DeepLearning/Lab-thuc-hanh/Lab-1/pytorch_implement/main.py --model 1-layer
# !python /kaggle/working/DeepLearning/Lab-thuc-hanh/Lab-1/pytorch_implement/main.py --model 3-layers
# Out:
# Cloning into 'DeepLearning'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 40 (delta 8), reused 40 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (40/40), 23.26 MiB | 27.95 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# 2025-10-23 14:56:02,865 - INFO - Đang sử dụng thiết bị: cuda
# 2025-10-23 14:56:02,866 - INFO - Đang tải dữ liệu MNIST...
# 100%|██████████████████████████████████████| 9.91M/9.91M [00:00<00:00, 38.8MB/s]
# 100%|███████████████████████████████████████| 28.9k/28.9k [00:00<00:00, 996kB/s]
# 100%|██████████████████████████████████████| 1.65M/1.65M [00:00<00:00, 10.1MB/s]
# 100%|██████████████████████████████████████| 4.54k/4.54k [00:00<00:00, 15.8MB/s]
# 2025-10-23 14:56:05,026 - INFO - Tải dữ liệu hoàn tất.
# 2025-10-23 14:56:05,031 - INFO - --- Đã chọn mô hình: MLP 1-Layer (SGD+Momentum) ---
# ...
